# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('thinkschool_non_shorts.csv')

# %%
df.head()
# Out:
#       video_id                                              title  \
# 0  fP7jNb4hT8M     Smart Founders Don’t Fear AI, They Partner It!
# 1  H088ypbYuDw  100x Your Brand in 60 Minutes with These PROVE...
# 2  wO1eJMRMvyE           From ₹0 to ₹1500 CR: The Mensa Playbook!
# 3  WU1441n9Ev0         Insight-driven brands always win in India!
# 4  jBEOdMKAkEU  BYD vs Tesla: How CHINA Beat ELON MUSK at His ...
#
#            published_at  view_count  like_count  comment_count    duration  \
# 0  2025-11-23T15:04:55Z       23500         847              4     PT1M14S
# 1  2025-11-21T13:42:00Z      120903        2411            132  PT1H20M26S
# 2  2025-11-21T13:31:11Z       50437        1464             27     PT2M13S
# 3  2025-11-16T06:30:14Z       67227        1130             10      PT1M5S
# 4  2025-11-11T13:02:48Z      641442       16666            742    PT22M33S
#
#    hours  minutes  seconds podcast  total_seconds  duration_minutes  \
# ...

# %%
podcast_df = df[df['podcast'] == "Yes"].copy()

# %%
podcast_df.to_csv("podcast_dataset.csv", index=False)

# %%
non_podcast_df = df[df['podcast'] != "Yes"].copy()

# %%
non_podcast_df.t
